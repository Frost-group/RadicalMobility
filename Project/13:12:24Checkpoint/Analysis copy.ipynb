# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

file_path = 'Data copy.xlsx' 
Base1 = pd.read_excel(file_path, sheet_name='Base 1')  
Base2 = pd.read_excel(file_path, sheet_name='Base 2')  
Base3 = pd.read_excel(file_path, sheet_name='Base 3')  
Base4 = pd.read_excel(file_path, sheet_name='Base 4')  
Katherine = pd.read_excel(file_path, sheet_name='Katherine')  
Blatter = pd.read_excel(file_path, sheet_name='Blatter')

# %% [markdown]
# # Comparison of funcionalisations of the 2x monomers and 2x dimers:

# %% [markdown]
# ##### (Sorry molecules are in a random order, its just the order I worked on things chronologically!)

# %% [markdown]
# ### Base 3 Functional Group comparison

# %%
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(Base3['Molecule'], Base3['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Electron')
ax1.plot(Base3['Molecule'], Base3['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Hole')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-6, 10e1)
ax1.legend()
ax1.set_title('Base 3')
img = mpimg.imread('Images/Base3.png')  
image_ax = fig.add_axes([0.8, 0.1, 0.8, 0.5])  
image_ax.imshow(img)
image_ax.axis('off')
# Out:
# (-0.5, 512.5, 518.5, -0.5)

# %% [markdown]
# ### Base 4 Functional group comparison

# %%
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(Base4['Molecule'], Base4['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Electron')
ax1.plot(Base4['Molecule'], Base4['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Hole')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-6, 10e1)
ax1.legend()
ax1.set_title('Base 4')
img = mpimg.imread('Images/Base4.png')  
image_ax = fig.add_axes([0.8, 0.1, 0.8, 0.5])  
image_ax.imshow(img)
image_ax.axis('off')
# Out:
# (-0.5, 947.5, 978.5, -0.5)

# %% [markdown]
# ### Small Katherine suggestions compared to small tBu derivatives

# %%
img1 = mpimg.imread('Images/Base3tBu.png')
img2 = mpimg.imread('Images/Base4tBu.png')
img3 = mpimg.imread('Images/Katherine3.png')
img4 = mpimg.imread('Images/Katherine4.png')

fig, (ax1) = plt.subplots(1, 1)
fig.subplots_adjust(left=0.1, right=0.9, top=0.7)  

ax1.plot(Base3.iloc[0:1]['300K'], Base3.iloc[0:1]['e- 𝜇 (cm^2/V·s)'], marker='x', color='blue', linestyle='', label='Electron')
ax1.plot(Base3.iloc[0:1]['300K'], Base3.iloc[0:1]['h+ 𝜇 (cm^2/V·s)'], marker='x', color='orange', linestyle='', label='Hole')
ax1.plot(Base4.iloc[0:1]['300K'], Base4.iloc[0:1]['e- 𝜇 (cm^2/V·s)'], marker='x', color='blue',linestyle='')
ax1.plot(Base4.iloc[0:1]['300K'], Base4.iloc[0:1]['h+ 𝜇 (cm^2/V·s)'], marker='x', color='orange',linestyle='')
ax1.plot(Katherine.iloc[2:4]['Molecule'], Katherine.iloc[2:4]['e- 𝜇 (cm^2/V·s)'], marker='x', color='blue', linestyle='')
ax1.plot(Katherine.iloc[2:4]['Molecule'], Katherine.iloc[2:4]['h+ 𝜇 (cm^2/V·s)'], marker='x', color='orange',linestyle='')


ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.legend()

ax_img1 = fig.add_axes([0.1, 0.47, 2, 0.3])  
ax_img2 = fig.add_axes([0.35, 0.47, 2, 0.3])
ax_img3 = fig.add_axes([0.1, 0.15, 2, 0.3])
ax_img4 = fig.add_axes([0.35, 0.15, 2, 0.3])

for ax_img, img in zip([ax_img1, ax_img2, ax_img3, ax_img4], [img1, img2, img3, img4]):
    ax_img.imshow(img)
    ax_img.axis('off')

plt.show()

# %% [markdown]
# ### Comparison of all small molecules

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
ax1.plot(Base3['Molecule'], Base3['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax2.plot(Base4['Molecule'], Base4['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax3.plot(Katherine.iloc[2:4]['Molecule'], Katherine.iloc[2:4]['e- 𝜇 (cm^2/V·s)'], marker='x', linestyle='')
ax1.plot(Base3['Molecule'], Base3['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax2.plot(Base4['Molecule'], Base4['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax3.plot(Katherine.iloc[2:4]['Molecule'], Katherine.iloc[2:4]['h+ 𝜇 (cm^2/V·s)'], marker='x', linestyle='')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.set_title('Base 3')
ax2.set_yscale('log')
ax2.set_xlabel('Group')
ax2.set_ylim(10e-5, 10e1)
ax2.set_title('Base 4')
ax3.set_yscale('log')
ax3.set_xlabel('Group')
ax3.set_ylim(10e-5, 10e1)
ax3.set_title('Katherine')
# Out:
# Text(0.5, 1.0, 'Katherine')

# %% [markdown]
# ### Base 1 Functional Group Comparison

# %%
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(Base1['Molecule'], Base1['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Electron')
ax1.plot(Base1['Molecule'], Base1['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Hole')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-6, 10e1)
ax1.legend()
ax1.set_title('Base 1')
img = mpimg.imread('Images/Base1.png')  
image_ax = fig.add_axes([0.8, 0.3, 0.8, 0.4])  
image_ax.imshow(img)
image_ax.axis('off')
# Out:
# (-0.5, 729.5, 443.5, -0.5)

# %% [markdown]
# ### Base 2 Functional Group Comparison

# %%
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(Base2['Molecule'], Base2['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Electron')
ax1.plot(Base2['Molecule'], Base2['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Hole')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-6, 10e1)
ax1.legend()
ax1.set_title('Base 2')
img = mpimg.imread('Images/Base2.png')  
image_ax = fig.add_axes([0.8, 0.3, 0.8, 0.4])  
image_ax.imshow(img)
image_ax.axis('off')
# Out:
# (-0.5, 636.5, 384.5, -0.5)

# %%
img1 = mpimg.imread('Images/Base1tBu.png')
img2 = mpimg.imread('Images/Base2tBu.png')
img3 = mpimg.imread('Images/Katherine1.png')
img4 = mpimg.imread('Images/Katherine2.png')

fig, (ax1) = plt.subplots(1, 1)
fig.subplots_adjust(left=0.1, right=0.9, top=0.7)  

ax1.plot(Base1[0:1]['300K'], Base1[0:1]['e- 𝜇 (cm^2/V·s)'], marker='x', color='blue', linestyle='', label='Electron')
ax1.plot(Base2[0:1]['300K'], Base2[0:1]['e- 𝜇 (cm^2/V·s)'], marker='x', linestyle='', color='blue')
ax1.plot(Katherine.iloc[0:2]['Molecule'], Katherine.iloc[0:2]['e- 𝜇 (cm^2/V·s)'], marker='x', color='blue', linestyle='')
ax1.plot(Base1[0:1]['300K'], Base1[0:1]['h+ 𝜇 (cm^2/V·s)'], marker='x', linestyle='', color='orange', label='Hole')
ax1.plot(Base2[0:1]['300K'], Base2[0:1]['h+ 𝜇 (cm^2/V·s)'], marker='x', linestyle='', color='orange')
ax1.plot(Katherine.iloc[0:2]['Molecule'], Katherine.iloc[0:2]['h+ 𝜇 (cm^2/V·s)'], marker='x', linestyle='', color='orange')

ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.legend()

ax_img1 = fig.add_axes([0.15, 0.47, 2, 0.3])  
ax_img2 = fig.add_axes([0.6, 0.47, 2, 0.3])
ax_img3 = fig.add_axes([0.15, 0.15, 2, 0.3])
ax_img4 = fig.add_axes([0.6, 0.15, 2, 0.3])

for ax_img, img in zip([ax_img1, ax_img2, ax_img3, ax_img4], [img1, img2, img3, img4]):
    ax_img.imshow(img)
    ax_img.axis('off')

plt.show()

# %% [markdown]
# ### Comparison of All large molecules

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
ax1.plot(Base1['Molecule'], Base1['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax2.plot(Base2['Molecule'], Base2['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax3.plot(Katherine.iloc[0:2]['Molecule'], Katherine.iloc[0:2]['e- 𝜇 (cm^2/V·s)'], marker='x', linestyle='')
ax1.plot(Base1['Molecule'], Base1['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax2.plot(Base2['Molecule'], Base2['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '')
ax3.plot(Katherine.iloc[0:2]['Molecule'], Katherine.iloc[0:2]['h+ 𝜇 (cm^2/V·s)'], marker='x', linestyle='')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.set_title('Base 1')
ax2.set_yscale('log')
ax2.set_xlabel('Group')
ax2.set_ylim(10e-5, 10e1)
ax2.set_title('Base 2')
ax3.set_yscale('log')
ax3.set_xlabel('Group')
ax3.set_ylim(10e-5, 10e1)
ax3.set_title('Katherine')
# Out:
# Text(0.5, 1.0, 'Katherine')

# %% [markdown]
# ### Comparison of e- mobility for all molecules

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(12, 6))

functional_groups = np.unique(np.concatenate([Base1['Molecule'], Base2['Molecule'], Base3['Molecule'], Base4['Molecule'], Katherine['Molecule']]))

colors = plt.cm.get_cmap('tab10', len(functional_groups))  

group_color_map = {group: colors(i) for i, group in enumerate(functional_groups)}

for base_data, label in zip([Base1, Base2, Base3, Base4, Katherine, Blatter],
                            ['Base 1', 'Base 2', 'Base 3', 'Base 4', 'Katherine Suggestions']):

    for group in functional_groups:
    
        group_data = base_data[base_data['Molecule'] == group]

        ax1.scatter(group_data['300K'], group_data['e- 𝜇 (cm^2/V·s)'], 
                    c=[group_color_map[group]], label=group if base_data is Base1 else "", marker='x', alpha=0.7)

ax1.set_yscale('log')
ax1.set_xlabel('Molecule Group')
ax1.set_ylabel('Electron Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.axhline(y=1, color='black', linestyle=':', linewidth=1)

legend_handles = []
for group, color in group_color_map.items():
    legend_handles.append(plt.Line2D([0], [0], marker='x', color='w', markerfacecolor=color, markersize=10, label=group))

ax1.legend(title='Group')

plt.show()
# Out:
# /var/folders/2_/c3gs48z50d137n59njkyc0lr0000gs/T/ipykernel_1848/1875640536.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(functional_groups))

# %% [markdown]
# ### Comparison of h+ mobility for all molecules

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(12, 6))

functional_groups = np.unique(np.concatenate([Base1['Molecule'], Base2['Molecule'], Base3['Molecule'], Base4['Molecule'], Katherine['Molecule']]))

colors = plt.cm.get_cmap('tab10', len(functional_groups))  

group_color_map = {group: colors(i) for i, group in enumerate(functional_groups)}

for base_data, label in zip([Base1, Base2, Base3, Base4, Katherine],
                            ['Base 1', 'Base 2', 'Base 3', 'Base 4', 'Katherine Suggestions']):

    for group in functional_groups:
    
        group_data = base_data[base_data['Molecule'] == group]

        ax1.scatter(group_data['300K'], group_data['h+ 𝜇 (cm^2/V·s)'], 
                    c=[group_color_map[group]], label=group if base_data is Base1 else "", marker='x', alpha=0.7)

ax1.set_yscale('log')
ax1.set_xlabel('Molecule Group')
ax1.set_ylabel('Hole Mobility (cm^2/V·s)')
ax1.set_ylim(10e-5, 10e1)
ax1.axhline(y=1, color='black', linestyle=':', linewidth=1)

legend_handles = []
for group, color in group_color_map.items():
    legend_handles.append(plt.Line2D([0], [0], marker='x', color='w', markerfacecolor=color, markersize=10, label=group))

ax1.legend(title='Group')

plt.show()
# Out:
# /var/folders/2_/c3gs48z50d137n59njkyc0lr0000gs/T/ipykernel_1848/2041551992.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(functional_groups))

# %% [markdown]
# # Now, investigating the Helicene Derivatives

# %% [markdown]
# ### Blatter functionalisation comparison

# %%
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(Blatter['Molecule'], Blatter['e- 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Electron')
ax1.plot(Blatter['Molecule'], Blatter['h+ 𝜇 (cm^2/V·s)'], marker = 'x', linestyle = '', label='Hole')
ax1.set_yscale('log')
ax1.set_xlabel('Group')
ax1.set_ylabel('Mobility (cm^2/V·s)')
ax1.set_ylim(10e-6, 10e1)
ax1.legend()
ax1.set_title('Blatter')
img = mpimg.imread('Images/Blatter.png')  
image_ax = fig.add_axes([0.7, 0.3, 0.8, 0.4])  
image_ax.imshow(img)
image_ax.axis('off')
# Out:
# (-0.5, 968.5, 780.5, -0.5)
